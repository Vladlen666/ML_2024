# %% [markdown]
# Постановка задачи
# Требуется ознакомиться с выбранным набором данных, визуализировать данные, вычислить основные характеристики (среднее, разброс, корреляционную матрицу и т.д.), обработать данные   решить задачу классификации
#
# Описание датасета:
# Датасет содержит информацию о фильмах и сериалах, доступных на различных платформах, таких как Netflix. Он включает такие характеристики, как название, жанр, страны доступности, оценки на различных платформах (IMDb, Rotten Tomatoes, Metacritic), количество наград, даты выпуска, режиссеры, актеры, рейтинги зрителей, и другие метаданные, связанные с производством и выпуском контента. В этом датасете присутствуют как числовые, так и категориальные признаки, которые содержат значительную информацию для анализа и моделирования.
#
# Характеристики датасета:
#
# Title (Название): Название фильма или сериала.
#
# Genre (Жанр): Жанр контента, например, драма, комедия, ужасы и т.д.
#
# Tags (Теги): Дополнительные теги, описывающие контент.
#
# Languages (Языки): Языки, на которых доступен контент.
#
# Series or Movie (Сериал или фильм): Тип контента (сериал или фильм).
#
# Hidden Gem Score: Субъективная оценка уникальности или недооцененности контента.
#
# Country Availability (Доступность по странам): Список стран, в которых доступен контент.
#
# Runtime (Длительность): Продолжительность контента (в минутах).
#
# Director (Режиссер): Имя режиссера фильма или сериала.
#
# Writer (Сценарист): Имя сценариста.
#
# Actors (Актеры): Список главных актеров.
#
# View Rating (Рейтинг зрителей): Оценка зрителей, например, PG, R и т.д.
#
# IMDb Score (Оценка IMDb): Оценка на платформе IMDb.
#
# Rotten Tomatoes Score (Оценка Rotten Tomatoes): Оценка на платформе Rotten Tomatoes.
#
# Metacritic Score (Оценка Metacritic): Оценка на платформе Metacritic.
#
# Awards Received (Полученные награды): Количество полученных наград.
#
# Awards Nominated For (Номинации на награды): Количество номинаций на награды.
#
# Boxoffice (Кассовые сборы): Кассовые сборы фильма.
#
# Release Date (Дата выхода): Дата выхода контента.
#
# Netflix Release Date (Дата выхода на Netflix): Дата выхода на платформе Netflix.
#
# Production House (Продюсерская компания): Название продюсерской компании.
#
# Netflix Link (Ссылка на Netflix): Ссылка на контент на платформе Netflix.
#
# IMDb Link (Ссылка на IMDb): Ссылка на контент на платформе IMDb.
#
# Summary (Краткое описание): Краткое описание сюжета фильма или сериала.
#
# IMDb Votes (Количество голосов на IMDb): Количество голосов, оставленных пользователями на IMDb.
#
# Image (Изображение): Ссылка на изображение постера.
#
# Poster (Постер): Ссылка на постер контента.
#
# TMDb Trailer (Трейлер TMDb): Ссылка на трейлер на TMDb.
#
# Trailer Site (Сайт трейлера): Платформа, на которой размещен трейлер.
#
# Основной задачей является проведение анализа данных для определения ключевых факторов, влияющих на популярность фильмов и сериалов, представленных в датасете. Необходимо выявить закономерности между различными характеристиками контента и его успехом на различных платформах. Кроме того, планируется предсказать тип контента (фильм или сериал) на основе его характеристик.
#
# Импортируем необходимые библиотеки.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error
import numpy as np

# %% [markdown]
# Путь к файлу датасета

# %%
file_path = r'C:\Users\titanpc\Desktop\netflix-rotten-tomatoes-metacritic-imdb.csv'

# %% [markdown]
# Чтение датасета и вывод первых 5 строк

# %%
df = pd.read_csv(file_path)
df.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15480 entries, 0 to 15479
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  15480 non-null  object
#  1   Genre                  13770 non-null  object
#  2   Tags                   15413 non-null  object
#  3   Languages              13526 non-null  object
#  4   Series or Movie        15480 non-null  object
#  5   Hidden Gem Score       13379 non-null  float64
#  6   Country Availability   15461 non-null  object
#  7   Runtime                15479 non-null  object
#  8   Director               10772 non-null  object
#  9   Writer                 11150 non-null  object
#  10  Actors                 13555 non-null  object
#  11  View Rating            8456 non-null   object
#  12  IMDb Score             13381 non-null  float64
#  13  Rotten Tomatoes Score  6382 non-null   float64
# ...

# %% [markdown]
# Визуализировать данные и вычислить основные характеристики (среднее, разброс, корреляционную матрицу и т.д.):

# %%
# Построение матрицы графиков зависимостей для всех числовых признаков с использованием seaborn
sns.pairplot(df_cleaned, diag_kind='kde', plot_kws={'alpha': 0.5})
plt.suptitle('Матрица графиков зависимостей для числовых признаков', y=1.02)
plt.show()

# %% [markdown]
# IMDb Score и Rotten Tomatoes Score демонстрируют достаточно сильную положительную корреляцию.
#
# Metacritic Score также коррелирует с Rotten Tomatoes Score, что логично, учитывая, что оба являются критическими оценками.
#
# Hidden Gem Score и IMDb Score также показывают некоторое положительное взаимодействие.

# %%
corr_matrix = df.corr(numeric_only=True)

# Установка размеров графика и построение тепловой карты корреляций
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Корреляционная матрица между числовыми признаками')
plt.show()

# Определение основных корреляций
high_corr = corr_matrix[(corr_matrix > 0.7) & (corr_matrix < 1.0)]
high_corr_pairs = high_corr.stack().reset_index()
high_corr_pairs.columns = ['Feature 1', 'Feature 2', 'Correlation']

# Отображение наиболее значимых корреляций
high_corr_pairs.sort_values(by='Correlation', ascending=False, inplace=True)
high_corr_pairs.dropna().head(10)
# Out:
#                Feature 1              Feature 2  Correlation
# 3  Rotten Tomatoes Score       Metacritic Score     0.903345
# 5       Metacritic Score  Rotten Tomatoes Score     0.903345
# 6        Awards Received   Awards Nominated For     0.817262
# 7   Awards Nominated For        Awards Received     0.817262
# 1             IMDb Score       Metacritic Score     0.717715
# 4       Metacritic Score             IMDb Score     0.717715
# 0             IMDb Score  Rotten Tomatoes Score     0.710922
# 2  Rotten Tomatoes Score             IMDb Score     0.710922

# %% [markdown]
# На основе матрицы видно несколько значимых корреляций:
#
# Rotten Tomatoes Score и Metacritic Score имеют очень высокую корреляцию (0.9), что говорит о том, что оценки этих двух платформ часто схожи.
#
# IMDb Score имеет высокую корреляцию как с Rotten Tomatoes Score (0.71), так и с Metacritic Score (0.72). Это показывает, что оценки на IMDb также согласуются с оценками критиков.
#
# Awards Received и Awards Nominated For имеют высокую корреляцию (0.82), что естественно, так как получение наград тесно связано с количеством номинаций.
#
# IMDb Votes и Awards Nominated For также демонстрируют положительную корреляцию (0.5), что указывает на то, что фильмы с большим количеством голосов на IMDb часто номинируются на награды.

# %%
# Построение гистограммы для IMDb Score
sns.histplot(df['IMDb Score'], bins=20, kde=True)
plt.title('Гистограмма распределения оценок IMDb')
plt.xlabel('Оценка IMDb')
plt.ylabel('Количество фильмов и сериалов')
plt.show()

# %% [markdown]
# Гистограмма распределения оценок IMDb показывает, что большинство фильмов и сериалов получают оценки в диапазоне от 5 до 8.

# %%
# Rotten Tomatoes Score
sns.histplot(df['Rotten Tomatoes Score'], bins=20, kde=True)
plt.title('Гистограмма распределения оценок Rotten Tomatoes')
plt.xlabel('Оценка Rotten Tomatoes')
plt.ylabel('Количество фильмов и сериалов')
plt.show()

# Metacritic Score
sns.histplot(df['Metacritic Score'], bins=20, kde=True)
plt.title('Гистограмма распределения оценок Metacritic')
plt.xlabel('Оценка Metacritic')
plt.ylabel('Количество фильмов и сериалов')
plt.show()

# Runtime
sns.histplot(df['Runtime'], bins=20, kde=True)
plt.title('Гистограмма распределения длительности контента')
plt.xlabel('Длительность (мин)')
plt.ylabel('Количество фильмов и сериалов')
plt.show()

# %% [markdown]
# На графике видно, что большая часть контента имеет длительность от 1 до 2 часов, что соответствует средней продолжительности большинства фильмов. Также есть значительное количество контента с длительностью менее 30 минут — это могут быть короткометражные фильмы или эпизоды сериалов. Есть небольшой всплеск длительности более 2 часов, что может указывать на популярность некоторых долгих фильмов или спецвыпусков.

# %%
# Построение круговых диаграмм (диаграмм-пирога) для категориальных переменных

# 1. Series or Movie
df['Series or Movie'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8), startangle=90, colors=['skyblue', 'salmon'])
plt.title('Распределение контента: Сериалы или Фильмы')
plt.ylabel('')
plt.show()

# 2. View Rating
plt.figure(figsize=(12, 12))
explode = [0.1 if val < 5 else 0 for val in df['View Rating'].value_counts(normalize=True) * 100]  # Выделение сегментов с маленькими значениями
df['View Rating'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90, wedgeprops={'linewidth': 1, 'edgecolor': 'black'}, textprops={'fontsize': 12}, explode=explode)
plt.title('Распределение рейтингов зрителей')
plt.ylabel('')
plt.show()

# 3. Genre (показать распределение по основным жанрам)
top_genres = df['Genre'].value_counts().head(5)
top_genres.plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8), startangle=90, colormap='Accent')
plt.title('Распределение по основным жанрам')
plt.ylabel('')
plt.show()

# %% [markdown]
# Распределение контента (Сериалы или Фильмы): Большинство контента в датасете - фильмы (75.6%), тогда как сериалы составляют 24.4%.
#
# Распределение рейтингов зрителей: Значительное количество контента имеет рейтинг "R" (24.8%), "PG-13" (16.2%) и "Not Rated" (15.6%). Также есть некоторое разнообразие в других категориях.
#
# Распределение по основным жанрам: Наиболее популярным жанром является "Comedy" (33.6%), за ним следует "Drama" (28.7%). Также видны популярные комбинации жанров, такие как "Comedy, Drama" и "Drama, Romance".

# %%
# 1. Столбчатая диаграмма для топ-10 жанров
plt.figure(figsize=(12, 6))
sns.barplot(x=top_10_genres.index, y=top_10_genres.values, hue=top_10_genres.index, dodge=False, palette='viridis', legend=False)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Жанр')
plt.ylabel('Количество фильмов и сериалов')
plt.title('Топ-10 жанров')
plt.show()

# 2. График распределения длительности контента (Runtime) с разбиением по типу (сериал или фильм)
plt.figure(figsize=(12, 6))
sns.histplot(data=df, x='Runtime', hue='Series or Movie', multiple='stack', bins=30)
plt.xlabel('Длительность (мин)')
plt.ylabel('Количество фильмов и сериалов')
plt.title('Распределение длительности контента в зависимости от типа')
plt.show()

# 3. График количества наград по типу контента (фильм или сериал)
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Series or Movie', y='Awards Received', hue='Series or Movie', dodge=False, palette='Set2', legend=False)
plt.xlabel('Тип контента')
plt.ylabel('Количество полученных наград')
plt.title('Распределение количества наград по типу контента')
plt.show()

# 4. Парная диаграмма для основных оценок (IMDb, Rotten Tomatoes, Metacritic)
sns.pairplot(df[['IMDb Score', 'Rotten Tomatoes Score', 'Metacritic Score']], diag_kind='kde', plot_kws={'alpha': 0.5})
plt.suptitle('Парная диаграмма для основных оценок', y=1.02)
plt.show()

# %% [markdown]
# На столбчатой диаграмме, которая показывает топ-10 жанров, видно, что наиболее популярные жанры — это комедия и драма. Эти жанры часто представлены как в фильмах, так и в сериалах.
#
# Популярность жанров, таких как комедия, драма, также указывает на успешные кросс-жанровые форматы, которые привлекают широкий круг зрителей.
#
# Длительность контента варьируется в зависимости от типа. На гистограмме видно, что фильмы обычно имеют продолжительность около 90–120 минут, в то время как сериалы склонны к более коротким эпизодам.
#
# Большинство фильмов и сериалов укладываются в рамки длительности, характерные для их формата, что показывает оптимальные временные промежутки для привлечения зрителей.
#
# На показывающем распределение количества наград по типу контента (фильмы или сериалы), видно, что фильмы склонны получать больше наград в сравнении с сериалами.
#
# Возможно, это связано с тем, что фильмы участвуют в большем количестве фестивалей и премий, чем сериалы. При этом сериалы также получают свои награды, хотя и в меньших количествах, что видно из меньших медианных значений.
#
# Парная диаграмма для основных оценок показывает значительные положительные корреляции между всеми тремя платформами оценки. Наибольшая корреляция наблюдается между Rotten Tomatoes Score и Metacritic Score, что говорит о схожести критической оценки этих двух платформ.
#
# Оценка IMDb также коррелирует с остальными оценками, но с меньшей силой, так как эта оценка формируется непосредственно зрителями, а не профессиональными критиками.

# %% [markdown]
# Итоговые выводы:
#
# Анализ датасета Netflix, Rotten Tomatoes, Metacritic, IMDb позволил выявить несколько важных закономерностей и факторов, влияющих на успех контента:
#
# Популярность жанров и типов контента: Наиболее популярными жанрами являются комедия и драма, которые представлены как в фильмах, так и в сериалах. Фильмы получили большее количество наград по сравнению с сериалами, что может быть связано с их участием в большем количестве фестивалей и премий.
#
# Влияние оценок на награды: Высокие оценки на таких платформах, как Rotten Tomatoes, Metacritic и IMDb, положительно коррелируют с количеством полученных наград и номинаций. Это указывает на то, что качественный контент, признанный критиками и зрителями, имеет больше шансов на получение наград.
#
# Длительность контента: Анализ распределения длительности показал, что фильмы обычно имеют продолжительность около 90–120 минут, тогда как сериалы склонны к более коротким эпизодам. Это говорит о том, что оптимальная длительность зависит от типа контента и целевой аудитории.
#
# Корреляции между оценками: Наибольшая корреляция наблюдается между оценками на Rotten Tomatoes и Metacritic, что подтверждает сходство в методах оценки этих платформ. Оценка IMDb также коррелирует с другими платформами, но в меньшей степени, так как она формируется на основе отзывов зрителей, а не профессиональных критиков.

# %% [markdown]
# Сумма пропущенных значений по каждому столбцу:

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Title                        0
# Genre                     1710
# Tags                        67
# Languages                 1954
# Series or Movie              0
# Hidden Gem Score          2101
# Country Availability        19
# Runtime                      1
# Director                  4708
# Writer                    4330
# Actors                    1925
# View Rating               7024
# IMDb Score                2099
# Rotten Tomatoes Score     9098
# Metacritic Score         11144
# Awards Received           9405
# Awards Nominated For      7819
# Boxoffice                11473
# Release Date              2107
# Netflix Release Date         0
# Production House         10331
# Netflix Link                 0
# IMDb Link                 2303
# Summary                      9
# IMDb Votes                2101
# Image                        0
# Poster                    3638
# TMDb Trailer              8286
# Trailer Site              8286
# dtype: int64

# %%
# Заполнение пропущенных значений
df.fillna(df.mean(numeric_only=True), inplace=True)
df.fillna('unknown', inplace=True)

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Title                    0
# Genre                    0
# Tags                     0
# Languages                0
# Series or Movie          0
# Hidden Gem Score         0
# Country Availability     0
# Runtime                  0
# Director                 0
# Writer                   0
# Actors                   0
# View Rating              0
# IMDb Score               0
# Rotten Tomatoes Score    0
# Metacritic Score         0
# Awards Received          0
# Awards Nominated For     0
# Boxoffice                0
# Release Date             0
# Netflix Release Date     0
# Production House         0
# Netflix Link             0
# IMDb Link                0
# Summary                  0
# IMDb Votes               0
# Image                    0
# Poster                   0
# TMDb Trailer             0
# Trailer Site             0
# dtype: int64

# %% [markdown]
# Теперь пропущенных значений нет.

# %% [markdown]
# Преобразование категориальных признаков

# %%
label_encoders = {}
for column in df.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column].astype(str))
    label_encoders[column] = le

df.head()
# Out:
#    Title  Genre   Tags  Languages  Series or Movie  Hidden Gem Score  \
# 0   6812   1288   3007       1370                1               4.3
# 1   4918   1118   4526        135                0               7.0
# 2   2288   1598  12947        135                0               6.4
# 3    504   1464  11972       1400                1               7.7
# 4   7973   1033  10946        135                0               8.1
#
#    Country Availability  Runtime  Director  Writer  ...  Netflix Release Date  \
# 0                  6622        2      6229    4291  ...                  1822
# 1                  1305        0      1100    1254  ...                  1822
# 2                  1305        0       763    1127  ...                  1822
# 3                  1017        2      6724    9637  ...                  1822
# 4                  3937        0      5834    9637  ...                  1822
#
#    Production House  Netflix Link  IMDb Link  Summary  IMDb Votes  Image  \
# ...

# %% [markdown]
# Нормализация данных:

# %%
scaler = StandardScaler()
numeric_columns = df.select_dtypes(include=['number']).columns
normalized_data = scaler.fit_transform(df[numeric_columns])
df[numeric_columns] = normalized_data

# %% [markdown]
# Разделение данных на обучающую и тестовую выборки(20% данных отводятся на тестовую выборку):

# %%
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# %%
# Выбор оптимального значения k
optimal_k = neighbor_range[np.argmin(errors_test)]
print(f'Оптимальное количество ближайших соседей: {optimal_k}')

# Запуск классификатора с оптимальным количеством ближайших соседей
knn = KNeighborsClassifier(n_neighbors=optimal_k)
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)

# Оценка модели KNN
# Оценка модели KNN
accuracy_train_knn = accuracy_score(y_train, y_pred_train_knn)
accuracy_knn = accuracy_score(y_test, y_pred_knn)
print("Точность классификатора KNN на обучающей выборке:", accuracy_train_knn)
print("Точность классификатора KNN с оптимальным k на тестовой выборке:", accuracy_knn)
print("\nОтчет о классификации (KNN):")
print(classification_report(y_test, y_pred_knn))
# Out:
# Оптимальное количество ближайших соседей: 6
# Точность классификатора KNN на обучающей выборке: 0.9653585271317829
# Точность классификатора KNN с оптимальным k на тестовой выборке: 0.957687338501292
#
# Отчет о классификации (KNN):
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      2299
#            1       0.91      0.93      0.92       797
#
#     accuracy                           0.96      3096
#    macro avg       0.94      0.95      0.94      3096
# weighted avg       0.96      0.96      0.96      3096

# %%
# Визуализация ошибок на обучающей и тестовой выборках
plt.figure(figsize=(10, 6))
plt.plot(neighbor_range, errors_train, label='Ошибка на обучающей выборке', marker='o', linestyle='--', color='blue')
plt.plot(neighbor_range, errors_test, label='Ошибка на тестовой выборке', marker='o', linestyle='-', color='red')
plt.xlabel('Количество ближайших соседей (k)')
plt.ylabel('Среднеквадратичная ошибка')
plt.title('Выбор оптимального количества ближайших соседей')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Метод ближайших соседей  был выбран в первую очередь благодаря своей простоте и интуитивной понятности. Он не требует сложного обучения модели, а просто сохраняет все тренировочные данные и классифицирует новые объекты на основе их сходства с уже известными.
# метод также позволяет наглядно увидеть, как изменяется точность модели в зависимости от параметра k, что помогает понять влияние выбора гиперпараметров на модель. Однако KNN может быть менее эффективен на больших объемах данных, так как производительность падает с увеличением данных.
# На основе проведенного анализа и тестирования модели классификатора ближайших соседей, модель успешно обучилась и показала высокую точность на тестовой выборке. Точность на обучающей выборке составила больше 90%, что свидетельствует о том, что модель способна правильно обобщать данные.
